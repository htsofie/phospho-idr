# %% [markdown]
# # This notebook is to analyse the morf data set proteins
# Trying to ensure that the sequence from IDS other than Uniprot IDs exactly match the same sequence for corresponding protein ID to ensure that the mapped interfaces is correct

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Load compiled morf file
morf_data = pd.read_csv('../data/morf_interfaces.csv')

# %%
print(f"Total number of proteins in the morf data set: {len(morf_data)}")

print(f"# of proteins with exact match: {len(morf_data[morf_data['sequence_match'] == "exact"])}")

print(f"# of proteins with no exact match: {len(morf_data[morf_data['sequence_match'] == "not exact"])}")
# Out:
# Total number of proteins in the morf data set: 713
# # of proteins with exact match: 661
# # of proteins with no exact match: 6
